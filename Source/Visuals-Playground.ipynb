# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools

# %%
size = 10000
b = np.random.randint(1,3,(100,100))
b
# Out:
# array([[1, 2, 2, ..., 1, 1, 1],
#        [1, 1, 2, ..., 1, 1, 2],
#        [1, 1, 2, ..., 2, 1, 1],
#        ...,
#        [2, 1, 1, ..., 1, 2, 1],
#        [2, 2, 2, ..., 2, 1, 1],
#        [1, 1, 2, ..., 2, 2, 2]])

# %%
colors = itertools.cycle(["r", "b", "g"])

plt.imshow(b)

# %%
b = np.random.randint(1,10,(10,10))
b
# Out:
# array([[5, 5, 8, 6, 2, 2, 5, 6, 6, 7],
#        [6, 9, 4, 3, 2, 4, 1, 2, 2, 8],
#        [5, 8, 3, 2, 9, 6, 2, 3, 8, 4],
#        [2, 3, 5, 9, 5, 3, 9, 4, 6, 9],
#        [2, 8, 1, 8, 4, 7, 2, 9, 7, 9],
#        [9, 8, 5, 7, 1, 2, 7, 6, 6, 8],
#        [3, 8, 1, 9, 6, 6, 6, 8, 4, 8],
#        [4, 7, 4, 7, 5, 1, 2, 6, 2, 7],
#        [7, 5, 4, 7, 9, 7, 9, 1, 8, 6],
#        [5, 7, 4, 9, 6, 8, 3, 7, 1, 2]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import time

# # viridis = cm.get_cmap('viridis', 8)
# print(viridis)

# %%
def plot_examples(colormaps,size):
    
    """
    Helper function to plot data with associated colormap.
    """
    np.random.seed(19680801)
    data = np.random.randint(1,10,(size, size))
    n = len(colormaps)
    fig, axs = plt.subplots(1, n, figsize=(10,10),
                            constrained_layout=True, squeeze=False)
    for [ax, cmap] in zip(axs.flat, colormaps):
        psm = ax.pcolormesh(data, cmap=cmap, rasterized=True, vmin=0, vmax=10)
        fig.colorbar(psm, ax=ax)
    plt.show()

# %%
cmap = ListedColormap(["r","g","b","c","m","y","k","w","gold", "lawngreen"])


start = time.time()


plot_examples([cmap],10000)
end = time.time()
print(end - start)
# Out:
# 77.69362998008728
